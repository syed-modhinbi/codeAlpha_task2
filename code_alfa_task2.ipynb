# %%
# !pip install openai
print("FAQ Chatbot Ready (Free Version)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Bot: Goodbye!")
        break

    if "ai" in user.lower():
        print("Bot: AI means Artificial Intelligence, which allows machines to think like humans.")
    elif "python" in user.lower():
        print("Bot: Python is a programming language used in AI, ML and web development.")
    elif "machine learning" in user.lower():
        print("Bot: Machine Learning is a technique where systems learn from data.")
    else:
        print("Bot: Sorry, I can answer only basic FAQ questions.")
# Out:
# ...
# FAQ Chatbot Ready (Free Version)
#
# You: ai
# Bot: AI means Artificial Intelligence, which allows machines to think like humans.
# You: exit
# Bot: Goodbye!
